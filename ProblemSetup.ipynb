# %%
import numpy as np
from obspy.geodetics.base import gps2dist_azimuth, kilometer2degrees
import pandas as pd
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
path = '/Users/sydneydybing/SW4/strain/'

# %% [markdown]
# # Event and Station locations

# %%
# read in event location file 
event_file = 'M6_catalog_2004-2024.csv'
eventLocs = pd.read_csv(path + event_file, dtype = 'str')

# Multiple events? (if you only have one set this to false so that we dont try to plot those)
multipleEvents = False

# #Pick Which Event to Model, or just put your event here
event = eventLocs.iloc[11]

# # In addition to Event Locations Also feed me the maximum frequency you want to model
freqMax = 0.1 #Hz

# %%
eventLocs
# Out:
#                         time    latitude     longitude   depth   mag magType  \
# 0   2023-04-13T15:54:53.808Z      49.215     -129.6178       7     6     mww
# 1   2022-12-20T10:34:24.770Z      40.525      -124.423   17.91   6.4      mw
# 2   2022-11-22T16:39:05.789Z     30.7936     -116.3907      10   6.2     mww
# 3   2021-12-20T20:10:31.310Z  40.3901667      -124.298   27.04   6.2      mw
# 4   2021-07-08T22:49:48.110Z     38.5075  -119.4998333    7.45     6      mw
# 5   2020-05-15T11:03:27.176Z     38.1689     -117.8497     2.7   6.5      ml
# 6   2020-03-31T23:52:30.781Z     44.4646     -115.1175   12.06   6.5     mww
# 7   2019-12-25T03:36:01.626Z     50.6106      -129.963    6.58   6.3     mww
# 8   2019-12-23T20:56:23.555Z     50.5169     -129.7573      10     6     mww
# 9   2019-12-23T19:49:43.086Z     50.6071     -129.9372      10     6     mww
# 10  2019-08-29T15:07:58.646Z     43.5425     -127.8817      10   6.3     mww
# 11  2019-07-06T03:19:53.040Z     35.7695  -117.5993333       8   7.1      mw
# 12  2019-07-04T17:33:49.000Z  35.7053333  -117.5038333    10.5   6.4      mw
# 13  2019-07-04T04:30:44.424Z     51.2369     -130.5005      10   6.2     mww
# 14  2018-10-22T06:22:48.120Z      49.297     -129.7237      10   6.5     mww
# 15  2018-10-22T06:16:26.450Z     49.3346      -129.289      10   6.8     mww
# 16  2018-10-22T05:39:39.590Z     49.2586     -129.4124      10   6.5     mww
# 17  2018-08-22T09:31:45.530Z     43.5637     -127.7166      10   6.2     mww
# 18  2016-12-08T14:49:45.910Z     40.4535     -126.1936    8.45   6.6     mww
# 19  2014-08-24T10:20:44.070Z  38.2151667  -122.3123333   11.12  6.02      mw
# 20  2014-04-24T03:10:10.150Z     49.6388     -127.7316      10   6.5     mww
# 21  2014-03-10T05:18:13.430Z  40.8286667  -125.1338333  16.441   6.8      mw
# 22  2013-09-04T00:23:11.290Z     51.1832     -130.2245    9.92     6     mww
# 23  2013-09-03T20:19:06.340Z      51.244     -130.3971    2.73   6.1     mww
# 24  2012-12-14T10:36:01.590Z      31.095       -119.66      13   6.3     mww
# 25  2012-11-08T02:01:50.630Z      49.231      -128.477    13.7   6.1     mww
# 26  2012-04-11T22:41:46.040Z      43.584      -127.638       8     6     mwc
# 27  2011-09-09T19:41:34.150Z      49.535      -126.893      22   6.4     mww
# 28  2010-04-04T22:40:42.360Z  32.2861667  -115.2953333   9.987   7.2      mw
# 29  2010-01-10T00:27:39.320Z      40.652     -124.6925  28.737   6.5      mw
# 30  2008-01-10T01:37:19.000Z      43.785      -127.264      13   6.3     mwc
# 31  2005-06-17T06:21:42.590Z      40.773      -126.574      12   6.6     mwb
# 32  2005-06-15T02:50:54.190Z      41.292      -125.953      16   7.2     mwc
# 33  2004-11-02T10:02:12.820Z      49.277      -128.772      10   6.7     mwb
# 34  2004-07-19T08:01:49.460Z      49.623      -126.967    23.7   6.4     mwb
#
#     nst    gap     dmin     rms  ...                   updated  \
# 0   228     54    1.719    0.65  ...  2023-06-17T21:36:51.040Z
# 1    38    214   0.0818    0.18  ...  2023-12-13T02:59:56.915Z
# 2   164     61    0.494    0.75  ...  2023-03-30T07:15:48.466Z
# 3    33    170  0.06557    0.13  ...  2022-12-30T01:11:35.632Z
# 4    42    100  0.04846    0.06  ...  2023-10-18T17:44:37.561Z
# 5    27  55.79    0.357  0.2669  ...  2023-08-25T20:46:08.292Z
# 6   NaN     31    0.885    0.66  ...  2023-11-27T02:38:57.327Z
# 7   NaN     77    1.853    0.67  ...  2020-03-14T22:25:03.040Z
# 8   NaN     99    1.042    1.05  ...  2020-03-07T17:47:53.040Z
# 9   NaN    100    1.149    1.06  ...  2020-03-07T17:47:53.040Z
# 10  NaN     31    2.678    1.17  ...  2021-08-14T16:56:05.720Z
# 11   77     43  0.04616    0.22  ...  2024-01-04T03:30:09.226Z
# 12   62     47   0.1233    0.16  ...  2023-11-21T19:13:15.781Z
# 13  NaN     70    1.143    1.01  ...  2019-09-26T14:30:08.040Z
# 14  NaN     68    1.692    0.71  ...  2022-05-03T19:35:47.549Z
# 15  NaN     36    1.505    1.09  ...  2022-05-03T19:35:42.430Z
# 16  NaN     63    1.611    0.94  ...  2022-05-03T19:35:53.041Z
# 17  NaN     67    2.668    0.73  ...  2022-05-03T19:27:59.600Z
# 18  NaN     55    1.405    1.11  ...  2022-05-03T18:04:29.554Z
# 19  369     28  0.03604    0.18  ...  2022-05-03T18:17:55.653Z
# 20  NaN    NaN      NaN    0.85  ...  2022-08-06T23:23:06.892Z
# 21  112    229   0.6568    0.15  ...  2022-09-24T19:42:07.982Z
# 22  NaN     70    1.431    0.87  ...  2022-05-03T17:46:09.383Z
# 23  NaN     44    1.704    0.93  ...  2022-07-25T21:36:32.686Z
# 24  760   20.9      NaN    1.29  ...  2022-08-08T22:41:13.593Z
# 25  613    101      NaN    1.17  ...  2022-08-09T02:51:51.768Z
# 26  656   43.9      NaN     1.1  ...  2022-08-09T02:53:44.284Z
# 27  650   28.1      NaN    1.02  ...  2022-08-09T02:54:49.608Z
# 28   10    239   0.5137    0.11  ...  2023-11-21T20:25:22.190Z
# 29   51    220   0.3225     0.2  ...  2022-08-05T23:26:47.399Z
# 30  232   39.7      NaN    1.38  ...  2022-05-02T20:57:47.658Z
# 31  659   31.4      NaN    1.06  ...  2022-05-02T16:48:12.331Z
# 32  420   31.4      NaN     1.2  ...  2022-08-08T22:22:31.380Z
# 33  459   37.3      NaN    1.17  ...  2022-08-09T02:56:02.977Z
# 34  393   27.3      NaN    1.04  ...  2022-05-02T17:17:47.430Z
#
#                                  place        type horizontalError depthError  \
# 0                                  NaN  earthquake            5.71      1.776
# 1             15km WSW of Ferndale, CA  earthquake            0.67        0.4
# 2       28 km SW of Las Brisas, Mexico  earthquake            4.14      1.745
# 3                7km N of Petrolia, CA  earthquake            0.46       0.34
# 4                  Antelope Valley, CA  earthquake            0.14       0.25
# 5    Monte Cristo Range, NV Earthquake  earthquake             NaN        2.1
# 6                       Stanley, Idaho  earthquake             8.5        3.8
# 7     203 km W of Port McNeill, Canada  earthquake             7.2        1.3
# 8     189 km W of Port McNeill, Canada  earthquake             5.7        1.8
# 9     201 km W of Port McNeill, Canada  earthquake             4.4        1.8
# 10          285 km W of Bandon, Oregon  earthquake             6.9        1.8
# 11      Ridgecrest Earthquake Sequence  earthquake            0.19      31.61
# 12      Ridgecrest Earthquake Sequence  earthquake            0.15       0.36
# 13  250 km WNW of Port McNeill, Canada  earthquake             6.6        1.8
# 14   237 km SW of Port McNeill, Canada  earthquake             3.3        1.7
# 15   210 km SW of Port McNeill, Canada  earthquake               6        1.8
# 16   223 km SW of Port McNeill, Canada  earthquake             4.4        1.5
# 17          272 km W of Bandon, Oregon  earthquake             7.1        1.8
# 18    164 km W of Ferndale, California  earthquake             6.1        2.4
# 19                          South Napa  earthquake            0.11       0.15
# 20        107 km WSW of Vernon, Canada  earthquake             NaN        1.7
# 21  77 km WNW of Indianola, California  earthquake            0.64       1.88
# 22  230 km WNW of Port McNeill, Canada  earthquake             NaN        2.5
# 23  243 km WNW of Port McNeill, Canada  earthquake             NaN        3.7
# 24    279 km SSW of Avalon, California  earthquake             NaN        NaN
# 25        176 km WSW of Vernon, Canada  earthquake             NaN        3.3
# 26          266 km W of Bandon, Oregon  earthquake             NaN        NaN
# 27          66 km SW of Vernon, Canada  earthquake             NaN        NaN
# 28          12km SW of Delta, B.C., MX  earthquake            1.81      31.61
# 29   37 km WNW of Ferndale, California  earthquake            0.55       1.31
# 30        242 km WNW of Bandon, Oregon  earthquake             NaN        NaN
# 31    196 km W of Ferndale, California  earthquake             NaN        NaN
# 32  153 km W of Big Lagoon, California  earthquake             NaN        NaN
# 33   189 km SW of Port McNeill, Canada  earthquake             NaN        NaN
# 34          62 km SW of Vernon, Canada  earthquake             NaN        NaN
#
#    magError magNst    status locationSource magSource
# 0     0.032     96  reviewed             us        us
# 1       NaN      0  reviewed             nc        nc
# 2     0.029    118  reviewed             us        us
# 3       NaN      0  reviewed             nc        nc
# 4       NaN      0  reviewed             nc        nc
# 5       NaN    NaN  reviewed             nn        nn
# 6     0.021    212  reviewed             us        us
# 7     0.032     95  reviewed             us        us
# 8     0.038     66  reviewed             us        us
# 9      0.03    106  reviewed             us        us
# 10     0.04     60  reviewed             us        us
# 11    0.028    126  reviewed             ci        ci
# 12      NaN      6  reviewed             ci        ci
# 13    0.026    143  reviewed             us        us
# 14    0.071     19  reviewed             us        us
# 15    0.042     55  reviewed             us        us
# 16    0.046     46  reviewed             us        us
# 17    0.031     97  reviewed             us        us
# 18      NaN    NaN  reviewed             us        us
# 19      NaN      0  reviewed             nc        nc
# 20      NaN    NaN  reviewed            pgc        us
# 21      NaN      5  reviewed             nc        nc
# 22      NaN    NaN  reviewed             us        us
# 23      NaN    NaN  reviewed             us        us
# 24      NaN    NaN  reviewed             us        us
# 25      NaN    NaN  reviewed             us        us
# 26      NaN    NaN  reviewed             us      gcmt
# 27      NaN    NaN  reviewed             us        us
# 28      NaN      0  reviewed             ci        ci
# 29      NaN      8  reviewed             nc        nc
# 30      NaN    NaN  reviewed             us        us
# 31      NaN    NaN  reviewed             us        us
# 32      NaN    NaN  reviewed             us       hrv
# 33      NaN    NaN  reviewed             us        us
# 34      NaN    NaN  reviewed             us        us
#
# [35 rows x 22 columns]

# %%
event
# Out:
# time                     2019-07-06T03:19:53.040Z
# latitude                                  35.7695
# longitude                            -117.5993333
# depth                                           8
# mag                                           7.1
# magType                                        mw
# nst                                            77
# gap                                            43
# dmin                                      0.04616
# rms                                          0.22
# net                                            ci
# id                                     ci38457511
# updated                  2024-01-04T03:30:09.226Z
# place              Ridgecrest Earthquake Sequence
# type                                   earthquake
# horizontalError                              0.19
# depthError                                  31.61
# magError                                    0.028
# magNst                                        126
# status                                   reviewed
# locationSource                                 ci
# magSource                                      ci
# Name: 11, dtype: object

# %%
sta_file = 'bsm_metadata.csv'
stas = pd.read_csv(path + sta_file)

# %%
# Choose subset of stations
rc_stas = ['B072', 'B073', 'B075', 'B076', 'B078', 'B079', 'B081', 'B082', 'B084', 'B086', 'B087', 'B088', 'B089', 'B900', 'B901', 'B916', 'B917', 'B918', 'B921', 'B946'] # close to Ridgecrest
rc_stas_sub = ['B072', 'B079', 'B082', 'B087', 'B916', 'B917', 'B918', 'B921'] # subset of stations close to Ridgecrest - 4 super close, 2 west, 2 south
stas_sub = stas.query('BNUM in @rc_stas_sub').reset_index(drop = True)
stas_sub
# Out:
#    BNUM              NAME       LAT       LONG  ELEV(m) INSTALL_DATE  \
# 0  B072  goldhl072bcn2007  35.83100 -120.34500    397.7      8/27/07
# 1  B079  jackcn079bcs2006  35.71570 -120.20570    436.6     10/13/06
# 2  B082  pathfi082bcs2006  33.59818 -116.59600   1374.8      6/10/06
# 3  B087  fordra087bcs2006  33.49550 -116.60267   1139.0      6/17/06
# 4  B916  marips916bcs2008  36.19250 -117.66850   1859.9      3/13/08
# 5  B917  tonyso917bcs2008  35.38920 -117.25870   1125.9      7/14/08
# 6  B918  mtsprn918bcs2008  35.93570 -117.60170   1042.6      6/21/08
# 7  B921  randsb921bcs2008  35.58650 -117.46220    694.5       6/3/08
#
#   CH0(EofN)  BSM_Depth(m) SEISMOMETER_Depth(m)  PORE_DEPTH(m) DATA_START  ->  \
# 0     219.7         159.7                154.5            NaN   2007:239  ->
# 1     353.7         181.5                175.1          45.00   2006:286  ->
# 2     324.8         242.6                220.7          22.60   2006:162  ->
# 3     340.7         160.9                147.5          24.38   2006:194  ->
# 4     303.6         176.5                166.9            NaN   2008:073  ->
# 5     306.1         162.5              Unknown            NaN   2008:196  ->
# 6     288.9         196.7                189.9            NaN   2008:173  ->
# 7     340.5         147.4                139.9            NaN   2008:157  ->
#
#   DATA_END  GAP(m)    L_DATE  L0(cnts)  L1(cnts)  L2(cnts)  L3(cnts)  \
# 0  Present  0.0001  2007:253  47592395  52739856  51898099  51846814
# 1  Present  0.0001  2006:318  48042444  48981765  47787315  49995315
# 2  Present  0.0002  2006:335  49597819  53081549  47839224  49741765
# 3  Present  0.0002  2006:335  49940592  51287823  50044783  49977525
# 4  Present  0.0001  2008:090  55948375  53191200  55522127  49391430
# 5  Present  0.0001  2008:219  51200216  53318503  50164819  49964400
# 6  Present  0.0001  2008:245  56324863  55262353  53608304  55388642
# 7  Present  0.0001  2008:178  53324139  53302937  55141972  53475662
#
#                  REGION
# 0  Parkfield_California
# 1  Parkfield_California
# 2       Anza_California
# 3       Anza_California
# 4     Mojave_California
# 5     Mojave_California
# 6     Mojave_California
# 7     Mojave_California

# %% [markdown]
# # Plot Events and Stations

# %%
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = ccrs.PlateCarree())
plt.scatter(stas_sub['LONG'], stas_sub['LAT'], marker = 'v', label = 'Stations')
# Add station labels
[plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(stas_sub['LONG'], stas_sub['LAT'], stas_sub['BNUM'])]

if multipleEvents:
    plt.scatter(float(eventLocs['longitude']), float(eventLocs['latitude']), marker = 'o', edgecolors = 'darkorange', facecolors = 'orange', label = 'Event locations')

plt.scatter(float(event['longitude']), float(event['latitude']), marker = '*', facecolors = 'red', label = "Event to model")
plt.text(float(event['longitude']), float(event['latitude']), ('Ridgecrest M' + event['mag']))

ax.legend(loc = 'lower left')
ax.coastlines()
gl = ax.gridlines(draw_labels = True)
Plotlims = ax.get_extent()
plt.show()

# %%
# These values are roughly the rectangle that encompasses all of our points plus a little buffer
Plotlims
# Out:
# (-120.53245, -116.40855, 33.36065, 36.32735)

# %% [markdown]
# # Velocity Model Stuff

# %%
# Load velocity model data. Doing simple block model for my project - no topography or pfile
vmod = pd.read_csv(path + 'mojave.mod', sep = '\t')
# vmod
thicknesses = vmod.Thickness.values
Vps = vmod.Vp.values
Vss = vmod.Vs.values
rhos = vmod.rho.values
Qps = vmod.Qp.values
Qss = vmod.Qs.values
vmod
# Out:
#     Thickness    Vs    Vp    rho     Qs   Qp
# 0       0.002  0.45  1.70  2.000   22.5   45
# 1       0.004  0.65  1.80  2.100   32.5   65
# 2       0.006  0.85  1.80  2.100   42.5   85
# 3       0.008  0.95  1.90  2.100   47.5   95
# 4       0.010  1.15  2.00  2.200   57.5  115
# 5       0.070  1.40  2.80  2.300   70.0  140
# 6       0.200  1.70  3.40  2.400   85.0  170
# 7       0.200  2.00  3.90  2.500  100.0  200
# 8       0.200  2.30  4.30  2.600  115.0  230
# 9       0.300  2.50  4.40  2.650  125.0  250
# 10      2.000  2.80  5.10  2.700  140.0  280
# 11      2.000  3.30  6.00  2.750  165.0  330
# 12      1.000  3.45  6.10  2.800  172.5  345
# 13      5.000  3.60  6.15  2.825  180.0  360
# 14      5.000  3.65  6.32  2.850  182.5  365
# 15      5.000  3.70  6.55  2.900  185.0  370
# 16     10.000  3.80  6.80  2.950  190.0  380
# 17    999.000  4.50  7.80  3.200  225.0  450

# %%
# Add column to vmod with Vp/Vs ratios

Vp_Vses = []

for i in range(len(vmod)):
    Vp = Vps[i]
    Vs = Vss[i]
    Vp_Vs = Vp/Vs
    Vp_Vses.append(Vp_Vs)

vmod['Vp/Vs'] = Vp_Vses
vmod
# Out:
#     Thickness    Vs    Vp    rho     Qs   Qp     Vp/Vs
# 0       0.002  0.45  1.70  2.000   22.5   45  3.777778
# 1       0.004  0.65  1.80  2.100   32.5   65  2.769231
# 2       0.006  0.85  1.80  2.100   42.5   85  2.117647
# 3       0.008  0.95  1.90  2.100   47.5   95  2.000000
# 4       0.010  1.15  2.00  2.200   57.5  115  1.739130
# 5       0.070  1.40  2.80  2.300   70.0  140  2.000000
# 6       0.200  1.70  3.40  2.400   85.0  170  2.000000
# 7       0.200  2.00  3.90  2.500  100.0  200  1.950000
# 8       0.200  2.30  4.30  2.600  115.0  230  1.869565
# 9       0.300  2.50  4.40  2.650  125.0  250  1.760000
# 10      2.000  2.80  5.10  2.700  140.0  280  1.821429
# 11      2.000  3.30  6.00  2.750  165.0  330  1.818182
# 12      1.000  3.45  6.10  2.800  172.5  345  1.768116
# 13      5.000  3.60  6.15  2.825  180.0  360  1.708333
# 14      5.000  3.65  6.32  2.850  182.5  365  1.731507
# 15      5.000  3.70  6.55  2.900  185.0  370  1.770270
# 16     10.000  3.80  6.80  2.950  190.0  380  1.789474
# 17    999.000  4.50  7.80  3.200  225.0  450  1.733333

# %%
# Assign some values from the velocity model for later
# We need Vs min for computing the desired resolution for the domain
# We need the max Vp/Vs ratio, becuase the number of points per wavelength you need for good resolution is higher for high Vp/Vs
vs_min = vmod['Vs'].min()
VpVs_max = vmod['Vp/Vs'].max()
ind = vmod.index[vmod['Vp/Vs'] == VpVs_max] # Find row with the max to get the Vp and Vs values
Vp_fromVpVsmax = vmod['Vp'][ind]
Vs_fromVpVsmax = vmod['Vs'][ind]
val = (Vs_fromVpVsmax**2) / (Vp_fromVpVsmax**2 - 2*Vs_fromVpVsmax**2)

val
# Out:
# 0    0.081489
# dtype: float64

# %% [markdown]
# If val here was <0.1 then we'd have to worry about needing wayyyyy more points per wavelength (like 40 instead of 6-10), but we are okay here
#
# See ref: H.-O. Kreiss and N.A. Petersson. Boundary estimates for the elastic wave equation in almost incompressible materials. SIAM J. Numer. Anal., 50:1556–1580, 2012.

# %%
# Simplify the top 30 meters/5 layers to avoid Vp/Vs issue

new_thickness = 0
_Vps = 0
_Vss = 0
_rhos = 0
_Qps = 0
_Qss = 0 
counter = 0

for i in range(len(vmod[:5])):
    
    thickness = thicknesses[i]
    Vp = Vps[i]
    Vs = Vss[i]
    rho = rhos[i]
    Qp = Qps[i]
    Qs = Qss[i]

    new_thickness += thickness
    _Vps += Vp
    _Vss += Vs
    _rhos += rho
    _Qps += Qp
    _Qss += Qs

    counter += 1

print(counter)
print(new_thickness)
new_Vp = _Vps/counter
new_Vs = _Vss/counter
new_rho = _rhos/counter
new_Qp = _Qps/counter
new_Qs = _Qss/counter
new_VpVs = new_Vp/new_Vs
# Out:
# 5
# 0.03

# %%
vmod_simple = vmod.copy()
drop_top = vmod_simple.drop([0,1,2,3,4])
drop_top.loc[0] = [new_thickness, new_Vs, new_Vp, new_rho, new_Qs, new_Qp, new_VpVs]
new_vmod = drop_top.sort_index().reset_index(drop = True)
new_vmod
# Out:
#     Thickness    Vs    Vp    rho     Qs     Qp     Vp/Vs
# 0        0.03  0.81  1.84  2.100   40.5   81.0  2.271605
# 1        0.07  1.40  2.80  2.300   70.0  140.0  2.000000
# 2        0.20  1.70  3.40  2.400   85.0  170.0  2.000000
# 3        0.20  2.00  3.90  2.500  100.0  200.0  1.950000
# 4        0.20  2.30  4.30  2.600  115.0  230.0  1.869565
# 5        0.30  2.50  4.40  2.650  125.0  250.0  1.760000
# 6        2.00  2.80  5.10  2.700  140.0  280.0  1.821429
# 7        2.00  3.30  6.00  2.750  165.0  330.0  1.818182
# 8        1.00  3.45  6.10  2.800  172.5  345.0  1.768116
# 9        5.00  3.60  6.15  2.825  180.0  360.0  1.708333
# 10       5.00  3.65  6.32  2.850  182.5  365.0  1.731507
# 11       5.00  3.70  6.55  2.900  185.0  370.0  1.770270
# 12      10.00  3.80  6.80  2.950  190.0  380.0  1.789474
# 13     999.00  4.50  7.80  3.200  225.0  450.0  1.733333

# %%
# Check to make sure new val is okay
vs_min = new_vmod['Vs'].min()
VpVs_max = new_vmod['Vp/Vs'].max()
ind = new_vmod.index[new_vmod['Vp/Vs'] == VpVs_max] # Find row with the max to get the Vp and Vs values
Vp_fromVpVsmax = new_vmod['Vp'][ind]
Vs_fromVpVsmax = new_vmod['Vs'][ind]
val = (Vs_fromVpVsmax**2) / (Vp_fromVpVsmax**2 - 2*Vs_fromVpVsmax**2)

val
# Out:
# 0    0.316437
# dtype: float64

# %%
thicknesses = new_vmod.Thickness.values
Vps = new_vmod.Vp.values
Vss = new_vmod.Vs.values
rhos = new_vmod.rho.values
Qps = new_vmod.Qp.values
Qss = new_vmod.Qs.values

# %%
# Write new block lines

z1 = 0

for i in range(len(new_vmod)):
    thickness = thicknesses[i] * 1000
    Vp = int(Vps[i] * 1000)
    Vs = int(Vss[i] * 1000)
    rho = int(rhos[i] * 1000)
    Qp = int(Qps[i] * 1000)
    Qs = int(Qss[i] * 1000)

    z1 = int(z1)

    z2 = int(z1 + thickness)

    if i == range(len(new_vmod))[-1]:
        line = 'block vp=' + str(Vp) + ' vs=' + str(Vs) + ' rho=' + str(rho) + ' z1=' + str(z1)
    else:
        line = 'block vp=' + str(Vp) + ' vs=' + str(Vs) + ' rho=' + str(rho) + ' z1=' + str(z1) + ' z2=' + str(z2)
    z1 += thickness

    print(line)

depth_max = z2
# Out:
# block vp=1839 vs=810 rho=2100 z1=0 z2=30
# block vp=2800 vs=1400 rho=2300 z1=30 z2=100
# block vp=3400 vs=1700 rho=2400 z1=100 z2=300
# block vp=3900 vs=2000 rho=2500 z1=300 z2=500
# block vp=4300 vs=2300 rho=2600 z1=500 z2=700
# block vp=4400 vs=2500 rho=2650 z1=700 z2=1000
# block vp=5100 vs=2800 rho=2700 z1=1000 z2=3000
# block vp=6000 vs=3300 rho=2750 z1=3000 z2=5000
# block vp=6100 vs=3450 rho=2800 z1=5000 z2=6000
# block vp=6150 vs=3600 rho=2825 z1=6000 z2=11000
# block vp=6320 vs=3650 rho=2850 z1=11000 z2=16000
# block vp=6550 vs=3700 rho=2900 z1=16000 z2=21000
# block vp=6800 vs=3800 rho=2950 z1=21000 z2=31000
# block vp=7800 vs=4500 rho=3200 z1=31000

# %% [markdown]
# # Plot bounds of Velocity Model with station locations

# %%
Plotlims
# Out:
# (-120.53245, -116.40855, 33.36065, 36.32735)

# %%
# Station/event box
# Setup points for box for domain from above with only event and stations
x_evtsta = [Plotlims[0], Plotlims[1], Plotlims[1], Plotlims[0], Plotlims[0]]
y_evtsta = [Plotlims[2], Plotlims[2], Plotlims[3], Plotlims[3], Plotlims[2]]

# Add buffer to make it bigger, since we need the supergrid to be farther out at this max frequency
evtsta_buffer = 0.5
x_model_domain = [Plotlims[0]-evtsta_buffer, Plotlims[1]+evtsta_buffer, Plotlims[1]+evtsta_buffer, Plotlims[0]-evtsta_buffer, Plotlims[0]-evtsta_buffer]
y_model_domain = [Plotlims[2]-evtsta_buffer, Plotlims[2]-evtsta_buffer, Plotlims[3]+evtsta_buffer, Plotlims[3]+evtsta_buffer, Plotlims[2]-evtsta_buffer]

# %%
# Velocity model box
# For my project, I'm just using a block model so I can artificially set this up based on the station locs with a buffer
vmod_buffer = 0.3 # degrees - 0.1 degrees = 10 km
x_vmod = [Plotlims[0]-vmod_buffer, Plotlims[1]+vmod_buffer, Plotlims[1]+vmod_buffer, Plotlims[0]-vmod_buffer, Plotlims[0]-vmod_buffer]
y_vmod = [Plotlims[2]-vmod_buffer, Plotlims[2]-vmod_buffer, Plotlims[3]+vmod_buffer, Plotlims[3]+vmod_buffer, Plotlims[2]-vmod_buffer]

# %%
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = ccrs.PlateCarree())
plt.scatter(stas_sub['LONG'], stas_sub['LAT'], marker = 'v', label = 'Stations')
# Add station labels
[plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(stas_sub['LONG'], stas_sub['LAT'], stas_sub['BNUM'])]

if multipleEvents:
    plt.scatter(float(eventLocs['longitude']), float(eventLocs['latitude']), marker = 'o', edgecolors = 'darkorange', facecolors = 'orange', label = 'Event locations')

plt.scatter(float(event['longitude']), float(event['latitude']), marker = '*', facecolors = 'red', label = "Event to model")
plt.text(float(event['longitude']), float(event['latitude']), ('Ridgecrest M' + event['mag']))
ax.plot(x_evtsta, y_evtsta, color = 'skyblue', lw = 3, label = 'Station/event box')
ax.plot(x_model_domain, y_model_domain, color = 'red', lw = 3, label = 'Model domain box')
ax.plot(x_vmod, y_vmod, color = 'coral', lw = 3, label = 'Velocity model box')
ax.legend(loc = 'lower left')

ax.coastlines()

plt.show()

# %% [markdown]
# # Grid Spacing Math

# %%
# This is the relationship from the sw4 manual section 4.5, p 28
# npts should be between 6 and 10

def get_step_size(frequency_max, npts, Vs_min):
    H = Vs_min * 1000 / (npts * frequency_max)
    return H
    
step_size = get_step_size(freqMax, 10, vs_min)
print(f"Model grid spacing is {step_size} m ")
# Out:
# Model grid spacing is 810.0000000000001 m

# %% [markdown]
# Based on the grid spacing, we can now compute the thickeness of the supergrid layer. The supergrid layers are SUPER important because they help damp reflections on the edges of the domain and dramatically decreases the size of the domain you need and decreases computational time. The supergrid points are PART of your model domain. Default number of supergrid points is 30, less than 20 points will make your solution numerically unstable. Long wavelengths are harder to supress than short wavelengths

# %%
npts_supergrid = 30
supergrid_thickness = step_size * npts_supergrid
supergrid_thickness_deg = np.round(kilometer2degrees(supergrid_thickness/1000), 4)
print(f"Do not put event sources or receivers in the outer {supergrid_thickness} m of the domain \nor a buffer of ~{supergrid_thickness_deg} degrees")
# Out:
# Do not put event sources or receivers in the outer 24300.000000000004 m of the domain
# or a buffer of ~0.2185 degrees

# %% [markdown]
# The thickness of our supergrid layer is a lot smaller than the domain we are looking at so I think we can run with the values of lats and lons stored in x1 and y1 (the event/station box)

# %%
x_model_domain
# Out:
# [-121.03245, -115.90855, -115.90855, -121.03245, -121.03245]

# %%
y_model_domain
# Out:
# [32.86065, 32.86065, 36.82735, 36.82735, 32.86065]

# %%
Plotlims
# Out:
# (-120.53245, -116.40855, 33.36065, 36.32735)

# %%
lon_min = np.min(x_model_domain)
lon_max = np.max(x_model_domain)
lat_min = np.min(y_model_domain)
lat_max = np.max(y_model_domain)

# Setup points for box for model domain from above
x_sgrid = [x_model_domain[0]+supergrid_thickness_deg, x_model_domain[1]-supergrid_thickness_deg, x_model_domain[2]-supergrid_thickness_deg, x_model_domain[3]+supergrid_thickness_deg, x_model_domain[4]+supergrid_thickness_deg]
y_sgrid = [y_model_domain[0]+supergrid_thickness_deg, y_model_domain[1]+supergrid_thickness_deg, y_model_domain[2]-supergrid_thickness_deg, y_model_domain[3]-supergrid_thickness_deg, y_model_domain[4]+supergrid_thickness_deg]

# %% [markdown]
# # Plot with supergrid (and topography if I was including that - deleted some cells)

# %%
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = ccrs.PlateCarree())
plt.scatter(stas_sub['LONG'], stas_sub['LAT'], marker = 'v', label = 'Stations')
# Add station labels
[plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(stas_sub['LONG'], stas_sub['LAT'], stas_sub['BNUM'])]

if multipleEvents:
    plt.scatter(float(eventLocs['longitude']), float(eventLocs['latitude']), marker = 'o', edgecolors = 'darkorange', facecolors = 'orange', label = 'Event locations')

plt.scatter(float(event['longitude']), float(event['latitude']), marker = '*', facecolors = 'red', label = "Event to model")
plt.text(float(event['longitude']), float(event['latitude']), ('Ridgecrest M' + event['mag']))
ax.plot(x_evtsta, y_evtsta, color = 'skyblue', lw = 3, label = 'Station/event box')
ax.plot(x_vmod, y_vmod, color = 'coral', lw = 3, label = 'Velocity model box')
ax.plot(x_model_domain, y_model_domain, color = 'red', lw = 3, label = 'Model domain box')
ax.plot(x_sgrid, y_sgrid, color = 'darkgreen', lw = 1, label = 'Supergrid box')
ax.legend(loc = 'lower left')

ax.coastlines()

plt.show()

# %% [markdown]
# # Aggregate Info for .in Files

# %% [markdown]
# ### Grid Command info

# %%
# Compute cartesian locations for grid
X,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_min, lon_max)
Y,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_max, lon_min)

print('GRID COMMAND')
print(f"Size of grid - x and y in m: {np.round(X,-1), np.round(Y,-1)}")
print(f"Maximum depth (z) from on velocity model in m: {depth_max}")
print(f"Origin - lat lon of lower left corner of model domain: {lat_min:.3f}, {lon_min:.3f}")
#print(f"lat lon of upper right corner {lat_max:.3f}, {lon_max:.3f}")
print('az = 0 for this project')
print(f"Model grid spacing (h) should be at least {int(step_size)} m for a frequency max of {freqMax} Hz")
# Out:
# GRID COMMAND
# Size of grid - x and y in m: (479550.0, 440060.0)
# Maximum depth (z) from on velocity model in m: 1030000
# Origin - lat lon of lower left corner of model domain: 32.861, -121.032
# az = 0 for this project
# Model grid spacing (h) should be at least 810 m for a frequency max of 0.1 Hz
# /var/folders/yg/s8qp7lfs59g_tbwsx_wxkdx80000gn/T/ipykernel_77058/3382753130.py:2: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   X,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_min, lon_max)
# /var/folders/yg/s8qp7lfs59g_tbwsx_wxkdx80000gn/T/ipykernel_77058/3382753130.py:3: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   Y,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_max, lon_min)

# %% [markdown]
# ### Receiver Output Command Info

# %%
# set output type
out = 'strains'

# %%
for i in range(len(stas_sub)):
    print(f"rec lat={stas_sub['LAT'][i]:.3f} lon={stas_sub['LONG'][i]:.3f} depth={stas_sub['BSM_Depth(m)'][i]:.1f} variables={out} file={stas_sub['BNUM'][i]} usgsformat=0 sacformat=1")
# Out:
# rec lat=35.831 lon=-120.345 depth=159.7 variables=strains file=B072 usgsformat=0 sacformat=1
# rec lat=35.716 lon=-120.206 depth=181.5 variables=strains file=B079 usgsformat=0 sacformat=1
# rec lat=33.598 lon=-116.596 depth=242.6 variables=strains file=B082 usgsformat=0 sacformat=1
# rec lat=33.495 lon=-116.603 depth=160.9 variables=strains file=B087 usgsformat=0 sacformat=1
# rec lat=36.193 lon=-117.668 depth=176.5 variables=strains file=B916 usgsformat=0 sacformat=1
# rec lat=35.389 lon=-117.259 depth=162.5 variables=strains file=B917 usgsformat=0 sacformat=1
# rec lat=35.936 lon=-117.602 depth=196.7 variables=strains file=B918 usgsformat=0 sacformat=1
# rec lat=35.587 lon=-117.462 depth=147.4 variables=strains file=B921 usgsformat=0 sacformat=1

# %% [markdown]
# ### Memory Calculations

# %% [markdown]
# Appendix B says roughly 208 bytes/grid point for runs with topography
#
# BUT "For parallel runs, the memory per grid point will be somewhat higher, because of duplicated
# ghost points at the processor boundaries."

# %%
grid_pts = (X/step_size) * (Y/step_size) * (depth_max / step_size)
mem_per_point = 208
mem_gb = grid_pts * mem_per_point / 1e9
print(f"Rough approximation of memory is {np.round(mem_gb, 0)} GB for a maximum frequency of {freqMax} Hz")
# Out:
# Rough approximation of memory is 85.0 GB for a maximum frequency of 0.1 Hz

# %% [markdown]
# ### Maximum Grid spacing

# %% [markdown]
# To have 30 super grid points on the outside of the domain and at least 60 actual grid points in domain, you can't have a step size for your grid higher than:

# %%
h_max = np.min([X/120, Y/120, depth_max/90])
h_max
# Out:
# 3667.144036442354

# %% [markdown]
# ### Source line info

# %%
event
# Out:
# time                     2019-07-06T03:19:53.040Z
# latitude                                  35.7695
# longitude                            -117.5993333
# depth                                           8
# mag                                           7.1
# magType                                        mw
# nst                                            77
# gap                                            43
# dmin                                      0.04616
# rms                                          0.22
# net                                            ci
# id                                     ci38457511
# updated                  2024-01-04T03:30:09.226Z
# place              Ridgecrest Earthquake Sequence
# type                                   earthquake
# horizontalError                              0.19
# depthError                                  31.61
# magError                                    0.028
# magNst                                        126
# status                                   reviewed
# locationSource                                 ci
# magSource                                      ci
# Name: 11, dtype: object
