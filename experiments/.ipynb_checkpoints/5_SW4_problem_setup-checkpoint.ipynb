# %%
import numpy as np
from obspy.geodetics.base import gps2dist_azimuth, kilometer2degrees
import pandas as pd
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import os

# %%
path = '/Users/sydneydybing/SW4/strain/experiments/'

# %%
# Maximum frequency you want to model
freqMax = 0.1 #Hz

# %% [markdown]
# # Event and Station locations

# %%
# Get hypocenter locations from FQ log files

fqs_using = ['1','2','3','4']
risetimes_using = ['MH2017', 'MH2017+1', 'MH2017-1']
dirlist = os.listdir(path + 'hetero_rupts/logfiles/')

log_files = []
for file in dirlist:
    end = file.split('.')[1][-1]
    if end in fqs_using:
        # print(file)
        log_files.append(file)

event_ids = []
hypo_lons = []
hypo_lats = []
hypo_depths = []
rise_times = []
        
for log in log_files:
    
    event_id = log.split('.')[1][-1]

    flog = open(path + 'hetero_rupts/logfiles/' + log, 'r')
    while True:
        line = flog.readline()
        if 'Hypocenter (lon,lat,z[km])' in line:
            hypo = line.split(':')[1].split(',')
            hypo_lon = float(hypo[0].split(' (')[1])
            hypo_lat = float(hypo[1])
            hypo_depth = float(hypo[2].split(')')[0])
        elif line == '':
            break
    flog.close()
    
    for rise_time_type in risetimes_using:
        
        if rise_time_type == 'MH2017':
            rise_time = 2.8
        elif rise_time_type == 'MH2017+1':
            rise_time = 3.8
        else:
            rise_time = 1.8
        
        event_ids.append(event_id)
        hypo_lons.append(float(hypo_lon))
        hypo_lats.append(float(hypo_lat))
        hypo_depths.append(float(hypo_depth))
        rise_times.append(float(rise_time))
    
events = np.column_stack((np.array(event_ids), np.array(hypo_lons), np.array(hypo_lats), np.array(hypo_depths), np.array(rise_times)))

# %%
eventLocs = pd.DataFrame(events, columns = ['rupt_num', 'longitude', 'latitude', 'depth', 'rise_time'])
eventLocs.to_csv('/Users/sydneydybing/SW4/strain/experiments/homo_events.csv', index = False)
eventLocs
# Out:
#    rupt_num    longitude   latitude  depth rise_time
# 0         2  -117.622955  35.777562  14.58       2.8
# 1         2  -117.622955  35.777562  14.58       3.8
# 2         2  -117.622955  35.777562  14.58       1.8
# 3         3  -118.049495  36.180743   10.1       2.8
# 4         3  -118.049495  36.180743   10.1       3.8
# 5         3  -118.049495  36.180743   10.1       1.8
# 6         1  -117.583453  35.745836   10.1       2.8
# 7         1  -117.583453  35.745836   10.1       3.8
# 8         1  -117.583453  35.745836   10.1       1.8
# 9         4  -117.657729  35.824579   2.63       2.8
# 10        4  -117.657729  35.824579   2.63       3.8
# 11        4  -117.657729  35.824579   2.63       1.8

# %%
sta_file = 'bsm_metadata.csv'
stas = pd.read_csv(path + sta_file)

# %%
# Choose subset of stations
rc_stas = ['B072', 'B073', 'B075', 'B076', 'B078', 'B079', 'B081', 'B082', 'B084', 'B086', 'B087', 'B088', 'B089', 'B900', 'B901', 'B916', 'B917', 'B918', 'B921', 'B946'] # close to Ridgecrest
# rc_stas_sub = ['B072', 'B079', 'B082', 'B087', 'B916', 'B917', 'B918', 'B921'] # subset of stations close to Ridgecrest - 4 super close, 2 west, 2 south
rc_stas_sub = ['B916', 'B917', 'B918', 'B921']
stas_sub = stas.query('BNUM in @rc_stas_sub').reset_index(drop = True)
stas_sub
# Out:
#    BNUM              NAME      LAT      LONG  ELEV(m) INSTALL_DATE CH0(EofN)  \
# 0  B916  marips916bcs2008  36.1925 -117.6685   1859.9      3/13/08     303.6
# 1  B917  tonyso917bcs2008  35.3892 -117.2587   1125.9      7/14/08     306.1
# 2  B918  mtsprn918bcs2008  35.9357 -117.6017   1042.6      6/21/08     288.9
# 3  B921  randsb921bcs2008  35.5865 -117.4622    694.5       6/3/08     340.5
#
#    BSM_Depth(m) SEISMOMETER_Depth(m)  PORE_DEPTH(m) DATA_START  -> DATA_END  \
# 0         176.5                166.9            NaN   2008:073  ->  Present
# 1         162.5              Unknown            NaN   2008:196  ->  Present
# 2         196.7                189.9            NaN   2008:173  ->  Present
# 3         147.4                139.9            NaN   2008:157  ->  Present
#
#    GAP(m)    L_DATE  L0(cnts)  L1(cnts)  L2(cnts)  L3(cnts)             REGION
# 0  0.0001  2008:090  55948375  53191200  55522127  49391430  Mojave_California
# 1  0.0001  2008:219  51200216  53318503  50164819  49964400  Mojave_California
# 2  0.0001  2008:245  56324863  55262353  53608304  55388642  Mojave_California
# 3  0.0001  2008:178  53324139  53302937  55141972  53475662  Mojave_California

# %%
# Synthetic station grid

left_edge = -119
right_edge = -116
top_edge = 37
bottom_edge = 34.5

art_sta_lons = np.arange(left_edge, right_edge + 0.05, 0.25)
art_sta_lats = np.arange(bottom_edge, top_edge + 0.05, 0.25)

print(art_sta_lons.shape)
print(art_sta_lats.shape)

print(art_sta_lons)
print(art_sta_lats)

extra_sta_lons = []
extra_sta_lats = []

for idx in range(len(art_sta_lons)):
    
    lon = art_sta_lons[idx]
    
    for lat in art_sta_lats:
        
        extra_sta_lons.append(lon)
        extra_sta_lats.append(lat)
# Out:
# (13,)
# (11,)
# [-119.   -118.75 -118.5  -118.25 -118.   -117.75 -117.5  -117.25 -117.
#  -116.75 -116.5  -116.25 -116.  ]
# [34.5  34.75 35.   35.25 35.5  35.75 36.   36.25 36.5  36.75 37.  ]

# %% [markdown]
# # Plot Events and Stations

# %%
# Fault extent
min_lon = -118.2123
max_lon = -117.2121
min_lat = 35.3989
max_lat = 36.3284

# %%
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = ccrs.PlateCarree())

plt.plot([min_lon, max_lon], [max_lat, min_lat], color = 'red', label = 'Planar fault extent')    

plt.scatter(stas_sub['LONG'], stas_sub['LAT'], marker = 'v', label = 'Stations')
plt.scatter(extra_sta_lons, extra_sta_lats, marker = '+', color = 'skyblue', label = 'Extra stations')
# Add station labels
[plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(stas_sub['LONG'], stas_sub['LAT'], stas_sub['BNUM'])]

multipleEvents = True
if multipleEvents:
    plt.scatter(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), marker = 'o', edgecolors = 'black', facecolors = 'black', label = 'Event hypocenters')
    [plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), eventLocs['rupt_num'])]

ax.legend(loc = 'lower left')
ax.coastlines()
gl = ax.gridlines(draw_labels = True)
Plotlims = ax.get_extent()
plt.show()

# %%
# These values are roughly the rectangle that encompasses all of our points plus a little buffer
Plotlims
# Out:
# (-119.15, -115.85, 34.375, 37.125)

# %% [markdown]
# # Velocity Model Stuff

# %%
# Load velocity model data. Doing simple block model for my project - no topography or pfile
vmod = pd.read_csv(path + 'mojave.mod', sep = '\t')
# vmod
thicknesses = vmod.Thickness.values
Vps = vmod.Vp.values
Vss = vmod.Vs.values
rhos = vmod.rho.values
Qps = vmod.Qp.values
Qss = vmod.Qs.values
vmod
# Out:
#     Thickness    Vs    Vp    rho     Qs   Qp
# 0       0.002  0.45  1.70  2.000   22.5   45
# 1       0.004  0.65  1.80  2.100   32.5   65
# 2       0.006  0.85  1.80  2.100   42.5   85
# 3       0.008  0.95  1.90  2.100   47.5   95
# 4       0.010  1.15  2.00  2.200   57.5  115
# 5       0.070  1.40  2.80  2.300   70.0  140
# 6       0.200  1.70  3.40  2.400   85.0  170
# 7       0.200  2.00  3.90  2.500  100.0  200
# 8       0.200  2.30  4.30  2.600  115.0  230
# 9       0.300  2.50  4.40  2.650  125.0  250
# 10      2.000  2.80  5.10  2.700  140.0  280
# 11      2.000  3.30  6.00  2.750  165.0  330
# 12      1.000  3.45  6.10  2.800  172.5  345
# 13      5.000  3.60  6.15  2.825  180.0  360
# 14      5.000  3.65  6.32  2.850  182.5  365
# 15      5.000  3.70  6.55  2.900  185.0  370
# 16     10.000  3.80  6.80  2.950  190.0  380
# 17    999.000  4.50  7.80  3.200  225.0  450

# %%
# Add column to vmod with Vp/Vs ratios

Vp_Vses = []

for i in range(len(vmod)):
    Vp = Vps[i]
    Vs = Vss[i]
    Vp_Vs = Vp/Vs
    Vp_Vses.append(Vp_Vs)

vmod['Vp/Vs'] = Vp_Vses
vmod
# Out:
#     Thickness    Vs    Vp    rho     Qs   Qp     Vp/Vs
# 0       0.002  0.45  1.70  2.000   22.5   45  3.777778
# 1       0.004  0.65  1.80  2.100   32.5   65  2.769231
# 2       0.006  0.85  1.80  2.100   42.5   85  2.117647
# 3       0.008  0.95  1.90  2.100   47.5   95  2.000000
# 4       0.010  1.15  2.00  2.200   57.5  115  1.739130
# 5       0.070  1.40  2.80  2.300   70.0  140  2.000000
# 6       0.200  1.70  3.40  2.400   85.0  170  2.000000
# 7       0.200  2.00  3.90  2.500  100.0  200  1.950000
# 8       0.200  2.30  4.30  2.600  115.0  230  1.869565
# 9       0.300  2.50  4.40  2.650  125.0  250  1.760000
# 10      2.000  2.80  5.10  2.700  140.0  280  1.821429
# 11      2.000  3.30  6.00  2.750  165.0  330  1.818182
# 12      1.000  3.45  6.10  2.800  172.5  345  1.768116
# 13      5.000  3.60  6.15  2.825  180.0  360  1.708333
# 14      5.000  3.65  6.32  2.850  182.5  365  1.731507
# 15      5.000  3.70  6.55  2.900  185.0  370  1.770270
# 16     10.000  3.80  6.80  2.950  190.0  380  1.789474
# 17    999.000  4.50  7.80  3.200  225.0  450  1.733333

# %%
# Assign some values from the velocity model for later
# We need Vs min for computing the desired resolution for the domain
# We need the max Vp/Vs ratio, becuase the number of points per wavelength you need for good resolution is higher for high Vp/Vs
vs_min = vmod['Vs'].min()
VpVs_max = vmod['Vp/Vs'].max()
ind = vmod.index[vmod['Vp/Vs'] == VpVs_max] # Find row with the max to get the Vp and Vs values
Vp_fromVpVsmax = vmod['Vp'][ind]
Vs_fromVpVsmax = vmod['Vs'][ind]
val = (Vs_fromVpVsmax**2) / (Vp_fromVpVsmax**2 - 2*Vs_fromVpVsmax**2)

val
# Out:
# 0    0.081489
# dtype: float64

# %% [markdown]
# If val here was <0.1 then we'd have to worry about needing wayyyyy more points per wavelength (like 40 instead of 6-10), but we are okay here
#
# See ref: H.-O. Kreiss and N.A. Petersson. Boundary estimates for the elastic wave equation in almost incompressible materials. SIAM J. Numer. Anal., 50:1556–1580, 2012.

# %%
# Simplify the top 30 meters/5 layers to avoid Vp/Vs issue

new_thickness = 0
_Vps = 0
_Vss = 0
_rhos = 0
_Qps = 0
_Qss = 0 
counter = 0

for i in range(len(vmod[:5])):
    
    thickness = thicknesses[i]
    Vp = Vps[i]
    Vs = Vss[i]
    rho = rhos[i]
    Qp = Qps[i]
    Qs = Qss[i]

    new_thickness += thickness
    _Vps += Vp
    _Vss += Vs
    _rhos += rho
    _Qps += Qp
    _Qss += Qs

    counter += 1

print(counter)
print(new_thickness)
new_Vp = _Vps/counter
new_Vs = _Vss/counter
new_rho = _rhos/counter
new_Qp = _Qps/counter
new_Qs = _Qss/counter
new_VpVs = new_Vp/new_Vs
# Out:
# 5
# 0.03

# %%
vmod_simple = vmod.copy()
drop_top = vmod_simple.drop([0,1,2,3,4])
drop_top.loc[0] = [new_thickness, new_Vs, new_Vp, new_rho, new_Qs, new_Qp, new_VpVs]
new_vmod = drop_top.sort_index().reset_index(drop = True)
new_vmod
# Out:
#     Thickness    Vs    Vp    rho     Qs     Qp     Vp/Vs
# 0        0.03  0.81  1.84  2.100   40.5   81.0  2.271605
# 1        0.07  1.40  2.80  2.300   70.0  140.0  2.000000
# 2        0.20  1.70  3.40  2.400   85.0  170.0  2.000000
# 3        0.20  2.00  3.90  2.500  100.0  200.0  1.950000
# 4        0.20  2.30  4.30  2.600  115.0  230.0  1.869565
# 5        0.30  2.50  4.40  2.650  125.0  250.0  1.760000
# 6        2.00  2.80  5.10  2.700  140.0  280.0  1.821429
# 7        2.00  3.30  6.00  2.750  165.0  330.0  1.818182
# 8        1.00  3.45  6.10  2.800  172.5  345.0  1.768116
# 9        5.00  3.60  6.15  2.825  180.0  360.0  1.708333
# 10       5.00  3.65  6.32  2.850  182.5  365.0  1.731507
# 11       5.00  3.70  6.55  2.900  185.0  370.0  1.770270
# 12      10.00  3.80  6.80  2.950  190.0  380.0  1.789474
# 13     999.00  4.50  7.80  3.200  225.0  450.0  1.733333

# %%
# Check to make sure new val is okay
vs_min = new_vmod['Vs'].min()
VpVs_max = new_vmod['Vp/Vs'].max()
ind = new_vmod.index[new_vmod['Vp/Vs'] == VpVs_max] # Find row with the max to get the Vp and Vs values
Vp_fromVpVsmax = new_vmod['Vp'][ind]
Vs_fromVpVsmax = new_vmod['Vs'][ind]
val = (Vs_fromVpVsmax**2) / (Vp_fromVpVsmax**2 - 2*Vs_fromVpVsmax**2)

val
# Out:
# 0    0.316437
# dtype: float64

# %%
thicknesses = new_vmod.Thickness.values
Vps = new_vmod.Vp.values
Vss = new_vmod.Vs.values
rhos = new_vmod.rho.values
Qps = new_vmod.Qp.values
Qss = new_vmod.Qs.values

# %%
# Write new block lines

z1 = 0

for i in range(len(new_vmod)):
    thickness = thicknesses[i] * 1000
    Vp = int(Vps[i] * 1000)
    Vs = int(Vss[i] * 1000)
    rho = int(rhos[i] * 1000)
    Qp = int(Qps[i] * 1000)
    Qs = int(Qss[i] * 1000)

    z1 = int(z1)

    z2 = int(z1 + thickness)

    if i == range(len(new_vmod))[-1]:
        line = 'block vp=' + str(Vp) + ' vs=' + str(Vs) + ' rho=' + str(rho) + ' z1=' + str(z1)
    else:
        line = 'block vp=' + str(Vp) + ' vs=' + str(Vs) + ' rho=' + str(rho) + ' z1=' + str(z1) + ' z2=' + str(z2)
    z1 += thickness

    print(line)

depth_max = z2
# Out:
# block vp=1839 vs=810 rho=2100 z1=0 z2=30
# block vp=2800 vs=1400 rho=2300 z1=30 z2=100
# block vp=3400 vs=1700 rho=2400 z1=100 z2=300
# block vp=3900 vs=2000 rho=2500 z1=300 z2=500
# block vp=4300 vs=2300 rho=2600 z1=500 z2=700
# block vp=4400 vs=2500 rho=2650 z1=700 z2=1000
# block vp=5100 vs=2800 rho=2700 z1=1000 z2=3000
# block vp=6000 vs=3300 rho=2750 z1=3000 z2=5000
# block vp=6100 vs=3450 rho=2800 z1=5000 z2=6000
# block vp=6150 vs=3600 rho=2825 z1=6000 z2=11000
# block vp=6320 vs=3650 rho=2850 z1=11000 z2=16000
# block vp=6550 vs=3700 rho=2900 z1=16000 z2=21000
# block vp=6800 vs=3800 rho=2950 z1=21000 z2=31000
# block vp=7800 vs=4500 rho=3200 z1=31000

# %% [markdown]
# # Plot bounds of Velocity Model with station locations

# %%
Plotlims
# Out:
# (-119.15, -115.85, 34.375, 37.125)

# %%
# Station/event box
# Setup points for box for domain from above with only event and stations
x_evtsta = [Plotlims[0], Plotlims[1], Plotlims[1], Plotlims[0], Plotlims[0]]
y_evtsta = [Plotlims[2], Plotlims[2], Plotlims[3], Plotlims[3], Plotlims[2]]

# Add buffer to make it bigger, since we need the supergrid to be farther out at this max frequency
evtsta_buffer = 0.5
x_model_domain = [Plotlims[0]-evtsta_buffer, Plotlims[1]+evtsta_buffer, Plotlims[1]+evtsta_buffer, Plotlims[0]-evtsta_buffer, Plotlims[0]-evtsta_buffer]
y_model_domain = [Plotlims[2]-evtsta_buffer, Plotlims[2]-evtsta_buffer, Plotlims[3]+evtsta_buffer, Plotlims[3]+evtsta_buffer, Plotlims[2]-evtsta_buffer]

# %%
# Velocity model box
# For my project, I'm just using a block model so I can artificially set this up based on the station locs with a buffer
vmod_buffer = 0.3 # degrees - 0.1 degrees = 10 km
x_vmod = [Plotlims[0]-vmod_buffer, Plotlims[1]+vmod_buffer, Plotlims[1]+vmod_buffer, Plotlims[0]-vmod_buffer, Plotlims[0]-vmod_buffer]
y_vmod = [Plotlims[2]-vmod_buffer, Plotlims[2]-vmod_buffer, Plotlims[3]+vmod_buffer, Plotlims[3]+vmod_buffer, Plotlims[2]-vmod_buffer]

# %%
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = ccrs.PlateCarree())
plt.plot([min_lon, max_lon], [max_lat, min_lat], color = 'red', label = 'Planar fault extent')    

plt.scatter(stas_sub['LONG'], stas_sub['LAT'], marker = 'v', label = 'Stations')
plt.scatter(extra_sta_lons, extra_sta_lats, marker = '+', color = 'skyblue', label = 'Extra stations')
# Add station labels
[plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(stas_sub['LONG'], stas_sub['LAT'], stas_sub['BNUM'])]

multipleEvents = True
if multipleEvents:
    plt.scatter(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), marker = 'o', edgecolors = 'darkorange', facecolors = 'orange', label = 'Event locations')
    [plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), eventLocs['rupt_num'])]
    
ax.plot(x_evtsta, y_evtsta, color = 'skyblue', lw = 3, label = 'Station/event box')
ax.plot(x_model_domain, y_model_domain, color = 'red', lw = 3, label = 'Model domain box')
ax.plot(x_vmod, y_vmod, color = 'coral', lw = 3, label = 'Velocity model box')
ax.legend(loc = 'lower left')

ax.coastlines()

plt.show()

# %% [markdown]
# # Grid Spacing Math

# %%
# This is the relationship from the sw4 manual section 4.5, p 28
# npts should be between 6 and 10

def get_step_size(frequency_max, npts, Vs_min):
    H = Vs_min * 1000 / (npts * frequency_max)
    return H
    
step_size = get_step_size(freqMax, 10, vs_min)
print(f"Model grid spacing is {step_size} m ")
# Out:
# Model grid spacing is 810.0000000000001 m

# %% [markdown]
# Based on the grid spacing, we can now compute the thickeness of the supergrid layer. The supergrid layers are SUPER important because they help damp reflections on the edges of the domain and dramatically decreases the size of the domain you need and decreases computational time. The supergrid points are PART of your model domain. Default number of supergrid points is 30, less than 20 points will make your solution numerically unstable. Long wavelengths are harder to supress than short wavelengths

# %%
npts_supergrid = 30
supergrid_thickness = step_size * npts_supergrid
supergrid_thickness_deg = np.round(kilometer2degrees(supergrid_thickness/1000), 4)
print(f"Do not put event sources or receivers in the outer {supergrid_thickness} m of the domain \nor a buffer of ~{supergrid_thickness_deg} degrees")
# Out:
# Do not put event sources or receivers in the outer 24300.000000000004 m of the domain
# or a buffer of ~0.2185 degrees

# %% [markdown]
# The thickness of our supergrid layer is a lot smaller than the domain we are looking at so I think we can run with the values of lats and lons stored in x1 and y1 (the event/station box)

# %%
x_model_domain
# Out:
# [-119.65, -115.35, -115.35, -119.65, -119.65]

# %%
y_model_domain
# Out:
# [33.875, 33.875, 37.625, 37.625, 33.875]

# %%
Plotlims
# Out:
# (-119.15, -115.85, 34.375, 37.125)

# %%
lon_min = np.min(x_model_domain)
lon_max = np.max(x_model_domain)
lat_min = np.min(y_model_domain)
lat_max = np.max(y_model_domain)

# Setup points for box for model domain from above
x_sgrid = [x_model_domain[0]+supergrid_thickness_deg, x_model_domain[1]-supergrid_thickness_deg, x_model_domain[2]-supergrid_thickness_deg, x_model_domain[3]+supergrid_thickness_deg, x_model_domain[4]+supergrid_thickness_deg]
y_sgrid = [y_model_domain[0]+supergrid_thickness_deg, y_model_domain[1]+supergrid_thickness_deg, y_model_domain[2]-supergrid_thickness_deg, y_model_domain[3]-supergrid_thickness_deg, y_model_domain[4]+supergrid_thickness_deg]

# %% [markdown]
# # Plot with supergrid (and topography if I was including that - deleted some cells)

# %%
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = ccrs.PlateCarree())
plt.plot([min_lon, max_lon], [max_lat, min_lat], color = 'red', label = 'Planar fault extent')    

plt.scatter(stas_sub['LONG'], stas_sub['LAT'], marker = 'v', label = 'Stations')
plt.scatter(extra_sta_lons, extra_sta_lats, marker = '+', color = 'skyblue', label = 'Extra stations')
# Add station labels
[plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(stas_sub['LONG'], stas_sub['LAT'], stas_sub['BNUM'])]

multipleEvents = True
if multipleEvents:
    plt.scatter(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), marker = 'o', edgecolors = 'darkorange', facecolors = 'orange', label = 'Event locations')
    [plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), eventLocs['rupt_num'])]
    
plt.plot(-117.7593, 35.9323, 'o', color = 'violet', label = 'Fault extent')
plt.plot(-117.2944, 35.5028, 'o', color = 'violet', label = 'Fault extent')
ax.plot(x_evtsta, y_evtsta, color = 'skyblue', lw = 3, label = 'Station/event box')
ax.plot(x_vmod, y_vmod, color = 'coral', lw = 3, label = 'Velocity model box')
ax.plot(x_model_domain, y_model_domain, color = 'red', lw = 3, label = 'Model domain box')
ax.plot(x_sgrid, y_sgrid, color = 'darkgreen', lw = 1, label = 'Supergrid box')
ax.legend(loc = 'lower left')

ax.coastlines()
gl = ax.gridlines(draw_labels = True)

plt.show()

# %% [markdown]
# # Aggregate Info for .in Files

# %% [markdown]
# ### Grid Command info

# %%
# Compute cartesian locations for grid
Y,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_min, lon_max)
X,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_max, lon_min)

print('GRID COMMAND')
print(f"Size of grid - x and y in m: {np.round(X,-1), np.round(Y,-1)}")
print(f"Maximum depth (z) from on velocity model in m: {depth_max}")
print(f"Origin - lat lon of lower left corner of model domain: {lat_min:.3f}, {lon_min:.3f}")
print(f"lat lon of upper right corner of model domain: {lat_max:.3f}, {lon_max:.3f}")
print('az = 0 for this project')
print(f"Model grid spacing (h) should be at least {int(step_size)} m for a frequency max of {freqMax} Hz")
print('')

print(f"grid x={int(X)} y={int(Y)} z=1030000 lat={lat_min:.3f} lon={lon_min:.3f} az=0 h={int(step_size)}")
# Out:
# GRID COMMAND
# Size of grid - x and y in m: (416080.0, 397810.0)
# Maximum depth (z) from on velocity model in m: 1030000
# Origin - lat lon of lower left corner of model domain: 33.875, -119.650
# lat lon of upper right corner of model domain: 37.625, -115.350
# az = 0 for this project
# Model grid spacing (h) should be at least 810 m for a frequency max of 0.1 Hz
#
# grid x=416079 y=397806 z=1030000 lat=33.875 lon=-119.650 az=0 h=810
# /var/folders/yg/s8qp7lfs59g_tbwsx_wxkdx80000gn/T/ipykernel_29593/3230086842.py:2: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   Y,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_min, lon_max)
# /var/folders/yg/s8qp7lfs59g_tbwsx_wxkdx80000gn/T/ipykernel_29593/3230086842.py:3: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   X,_,_ = gps2dist_azimuth(lat_min, lon_min, lat_max, lon_min)

# %% [markdown]
# ### Receiver Output Command Info

# %%
# set output type
out1 = 'strains'
out2 = 'displacement'

# %%
# Add the real GNSS station locations

gnss_stas = pd.read_csv(path + 'GNSS_stas.txt', delimiter = '\t', names = ['LONG', 'LAT', 'BNUM'])
# gnss_stas

# %%
# Pick out the stations within the domain

gnss_sub = gnss_stas[(gnss_stas['LONG'] < x_evtsta[1]-0.1) & (gnss_stas['LONG'] > x_evtsta[0]+0.1) & (gnss_stas['LAT'] > y_evtsta[1]+0.1) & (gnss_stas['LAT'] < y_evtsta[2]-0.1)].reset_index()
# gnss_sub

# %%
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = ccrs.PlateCarree())
plt.plot([min_lon, max_lon], [max_lat, min_lat], color = 'red', label = 'Planar fault extent')    

plt.scatter(stas_sub['LONG'], stas_sub['LAT'], marker = 'v', label = 'Stations')
plt.scatter(extra_sta_lons, extra_sta_lats, marker = '+', color = 'skyblue', label = 'Extra stations')
plt.scatter(gnss_sub['LONG'], gnss_sub['LAT'], marker = 'v', color = 'green', label = 'GNSS stations')
# Add station labels
[plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(stas_sub['LONG'], stas_sub['LAT'], stas_sub['BNUM'])]

multipleEvents = True
if multipleEvents:
    plt.scatter(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), marker = 'o', edgecolors = 'darkorange', facecolors = 'orange', label = 'Event locations')
    [plt.text(i, j, f'{name}', va = 'top', ha = 'left') for (i, j, name) in zip(eventLocs['longitude'].astype(float), eventLocs['latitude'].astype(float), eventLocs['rupt_num'])]
    
plt.plot(-117.7593, 35.9323, 'o', color = 'violet', label = 'Fault extent')
plt.plot(-117.2944, 35.5028, 'o', color = 'violet', label = 'Fault extent')
ax.plot(x_evtsta, y_evtsta, color = 'skyblue', lw = 3, label = 'Station/event box')
ax.plot(x_vmod, y_vmod, color = 'coral', lw = 3, label = 'Velocity model box')
ax.plot(x_model_domain, y_model_domain, color = 'red', lw = 3, label = 'Model domain box')
ax.plot(x_sgrid, y_sgrid, color = 'darkgreen', lw = 1, label = 'Supergrid box')
ax.legend(loc = 'lower left')

ax.coastlines()

plt.show()

# %%
extra_sta_names = []
counter = 0
for i in range(len(extra_sta_lons)):
    counter += 1
    name = int(counter)
    extra_sta_names.append('E' + str(name))

extra_stas_array = np.column_stack((np.array(extra_sta_names), np.array(extra_sta_lons), np.array(extra_sta_lats)))
# print(extra_stas_array)

extra_stas = pd.DataFrame(extra_stas_array, columns = ['name', 'lon', 'lat'])
# extra_stas

extra_stas.to_csv('/Users/sydneydybing/SW4/strain/experiments/extra_stas.csv', index = False)

# %%
for i in range(len(stas_sub)):
    print(f"rec lat={stas_sub['LAT'][i]:.3f} lon={stas_sub['LONG'][i]:.3f} depth={stas_sub['BSM_Depth(m)'][i]:.1f} variables={out1} file={stas_sub['BNUM'][i]+'s'} usgsformat=1 sacformat=0 writeEvery=50")
    print(f"rec lat={stas_sub['LAT'][i]:.3f} lon={stas_sub['LONG'][i]:.3f} depth={stas_sub['BSM_Depth(m)'][i]:.1f} variables={out2} file={stas_sub['BNUM'][i]+'d'} usgsformat=1 sacformat=0 writeEvery=50")
    
for j in range(len(gnss_sub)):
    print(f"rec lat={gnss_sub['LAT'][j]:.3f} lon={gnss_sub['LONG'][j]:.3f} depth=0 variables={out2} file={gnss_sub['BNUM'][j]+'d'} usgsformat=1 sacformat=0 writeEvery=50")

for k in range(len(extra_stas)):
    print(f"rec lat={extra_stas['lat'].astype(float)[k]:.3f} lon={extra_stas['lon'].astype(float)[k]:.3f} depth=0 variables={out1} file={extra_stas['name'][k]+'s'} usgsformat=1 sacformat=0 writeEvery=50")
    print(f"rec lat={extra_stas['lat'].astype(float)[k]:.3f} lon={extra_stas['lon'].astype(float)[k]:.3f} depth=0 variables={out2} file={extra_stas['name'][k]+'d'} usgsformat=1 sacformat=0 writeEvery=50")
# Out:
# rec lat=36.193 lon=-117.668 depth=176.5 variables=strains file=B916s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.193 lon=-117.668 depth=176.5 variables=displacement file=B916d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.389 lon=-117.259 depth=162.5 variables=strains file=B917s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.389 lon=-117.259 depth=162.5 variables=displacement file=B917d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.936 lon=-117.602 depth=196.7 variables=strains file=B918s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.936 lon=-117.602 depth=196.7 variables=displacement file=B918d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.587 lon=-117.462 depth=147.4 variables=strains file=B921s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.587 lon=-117.462 depth=147.4 variables=displacement file=B921d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.878 lon=-118.074 depth=0 variables=displacement file=BEPKd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.287 lon=-116.080 depth=0 variables=displacement file=BKAPd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.919 lon=-117.012 depth=0 variables=displacement file=BSRYd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.565 lon=-117.671 depth=0 variables=displacement file=CCCCd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.829 lon=-116.336 depth=0 variables=displacement file=CDMTd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.072 lon=-117.573 depth=0 variables=displacement file=CPBNd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.517 lon=-118.613 depth=0 variables=displacement file=CTDMd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.755 lon=-116.430 depth=0 variables=displacement file=HCMNd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.760 lon=-117.800 depth=0 variables=displacement file=HIVId usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.662 lon=-118.474 depth=0 variables=displacement file=ISLKd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.699 lon=-116.209 depth=0 variables=displacement file=LDSWd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.090 lon=-116.940 depth=0 variables=displacement file=LNMTd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.675 lon=-116.815 depth=0 variables=displacement file=ORMTd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.614 lon=-117.532 depth=0 variables=displacement file=P091d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.606 lon=-117.994 depth=0 variables=displacement file=P093d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.071 lon=-116.629 depth=0 variables=displacement file=P462d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.022 lon=-117.165 depth=0 variables=displacement file=P463d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.531 lon=-117.789 depth=0 variables=displacement file=P466d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.570 lon=-118.091 depth=0 variables=displacement file=P467d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.976 lon=-118.118 depth=0 variables=displacement file=P468d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.835 lon=-118.879 depth=0 variables=displacement file=P553d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.792 lon=-118.848 depth=0 variables=displacement file=P554d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.771 lon=-118.545 depth=0 variables=displacement file=P556d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.944 lon=-118.656 depth=0 variables=displacement file=P557d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.822 lon=-118.541 depth=0 variables=displacement file=P560d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.421 lon=-118.754 depth=0 variables=displacement file=P567d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.254 lon=-118.126 depth=0 variables=displacement file=P568d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.667 lon=-118.260 depth=0 variables=displacement file=P570d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.039 lon=-118.006 depth=0 variables=displacement file=P579d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.621 lon=-117.192 depth=0 variables=displacement file=P580d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.510 lon=-117.729 depth=0 variables=displacement file=P581d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.634 lon=-117.549 depth=0 variables=displacement file=P582d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.987 lon=-117.543 depth=0 variables=displacement file=P583d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.535 lon=-117.281 depth=0 variables=displacement file=P586d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.621 lon=-117.110 depth=0 variables=displacement file=P589d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.117 lon=-117.365 depth=0 variables=displacement file=P590d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.152 lon=-118.016 depth=0 variables=displacement file=P591d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.238 lon=-117.304 depth=0 variables=displacement file=P592d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.388 lon=-117.205 depth=0 variables=displacement file=P593d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.897 lon=-117.390 depth=0 variables=displacement file=P594d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.698 lon=-117.403 depth=0 variables=displacement file=P595d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.717 lon=-116.029 depth=0 variables=displacement file=P603d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.937 lon=-116.671 depth=0 variables=displacement file=P604d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.205 lon=-116.763 depth=0 variables=displacement file=P615d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.425 lon=-117.893 depth=0 variables=displacement file=P616d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.142 lon=-116.104 depth=0 variables=displacement file=P618d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.526 lon=-116.122 depth=0 variables=displacement file=P619d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.785 lon=-116.145 depth=0 variables=displacement file=P620d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.152 lon=-118.017 depth=0 variables=displacement file=P811d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.152 lon=-118.017 depth=0 variables=displacement file=P812d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.508 lon=-117.923 depth=0 variables=displacement file=PBPPd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.339 lon=-117.683 depth=0 variables=displacement file=RAMTd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.644 lon=-116.625 depth=0 variables=displacement file=RDMTd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.875 lon=-118.193 depth=0 variables=displacement file=RSTPd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.607 lon=-117.388 depth=0 variables=displacement file=SCIAd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.971 lon=-116.299 depth=0 variables=displacement file=SHOSd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.158 lon=-118.415 depth=0 variables=displacement file=THCPd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.011 lon=-118.984 depth=0 variables=displacement file=WGPPd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.568 lon=-118.742 depth=0 variables=displacement file=WKPKd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.669 lon=-116.932 depth=0 variables=displacement file=WOMTd usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-119.000 depth=0 variables=strains file=E1s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-119.000 depth=0 variables=displacement file=E1d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-119.000 depth=0 variables=strains file=E2s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-119.000 depth=0 variables=displacement file=E2d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-119.000 depth=0 variables=strains file=E3s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-119.000 depth=0 variables=displacement file=E3d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-119.000 depth=0 variables=strains file=E4s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-119.000 depth=0 variables=displacement file=E4d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-119.000 depth=0 variables=strains file=E5s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-119.000 depth=0 variables=displacement file=E5d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-119.000 depth=0 variables=strains file=E6s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-119.000 depth=0 variables=displacement file=E6d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-119.000 depth=0 variables=strains file=E7s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-119.000 depth=0 variables=displacement file=E7d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-119.000 depth=0 variables=strains file=E8s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-119.000 depth=0 variables=displacement file=E8d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-119.000 depth=0 variables=strains file=E9s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-119.000 depth=0 variables=displacement file=E9d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-119.000 depth=0 variables=strains file=E10s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-119.000 depth=0 variables=displacement file=E10d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-119.000 depth=0 variables=strains file=E11s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-119.000 depth=0 variables=displacement file=E11d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.750 depth=0 variables=strains file=E12s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.750 depth=0 variables=displacement file=E12d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.750 depth=0 variables=strains file=E13s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.750 depth=0 variables=displacement file=E13d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.750 depth=0 variables=strains file=E14s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.750 depth=0 variables=displacement file=E14d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.750 depth=0 variables=strains file=E15s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.750 depth=0 variables=displacement file=E15d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.750 depth=0 variables=strains file=E16s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.750 depth=0 variables=displacement file=E16d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.750 depth=0 variables=strains file=E17s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.750 depth=0 variables=displacement file=E17d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.750 depth=0 variables=strains file=E18s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.750 depth=0 variables=displacement file=E18d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.750 depth=0 variables=strains file=E19s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.750 depth=0 variables=displacement file=E19d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.750 depth=0 variables=strains file=E20s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.750 depth=0 variables=displacement file=E20d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.750 depth=0 variables=strains file=E21s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.750 depth=0 variables=displacement file=E21d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.750 depth=0 variables=strains file=E22s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.750 depth=0 variables=displacement file=E22d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.500 depth=0 variables=strains file=E23s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.500 depth=0 variables=displacement file=E23d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.500 depth=0 variables=strains file=E24s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.500 depth=0 variables=displacement file=E24d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.500 depth=0 variables=strains file=E25s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.500 depth=0 variables=displacement file=E25d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.500 depth=0 variables=strains file=E26s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.500 depth=0 variables=displacement file=E26d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.500 depth=0 variables=strains file=E27s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.500 depth=0 variables=displacement file=E27d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.500 depth=0 variables=strains file=E28s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.500 depth=0 variables=displacement file=E28d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.500 depth=0 variables=strains file=E29s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.500 depth=0 variables=displacement file=E29d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.500 depth=0 variables=strains file=E30s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.500 depth=0 variables=displacement file=E30d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.500 depth=0 variables=strains file=E31s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.500 depth=0 variables=displacement file=E31d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.500 depth=0 variables=strains file=E32s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.500 depth=0 variables=displacement file=E32d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.500 depth=0 variables=strains file=E33s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.500 depth=0 variables=displacement file=E33d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.250 depth=0 variables=strains file=E34s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.250 depth=0 variables=displacement file=E34d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.250 depth=0 variables=strains file=E35s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.250 depth=0 variables=displacement file=E35d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.250 depth=0 variables=strains file=E36s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.250 depth=0 variables=displacement file=E36d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.250 depth=0 variables=strains file=E37s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.250 depth=0 variables=displacement file=E37d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.250 depth=0 variables=strains file=E38s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.250 depth=0 variables=displacement file=E38d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.250 depth=0 variables=strains file=E39s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.250 depth=0 variables=displacement file=E39d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.250 depth=0 variables=strains file=E40s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.250 depth=0 variables=displacement file=E40d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.250 depth=0 variables=strains file=E41s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.250 depth=0 variables=displacement file=E41d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.250 depth=0 variables=strains file=E42s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.250 depth=0 variables=displacement file=E42d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.250 depth=0 variables=strains file=E43s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.250 depth=0 variables=displacement file=E43d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.250 depth=0 variables=strains file=E44s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.250 depth=0 variables=displacement file=E44d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.000 depth=0 variables=strains file=E45s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-118.000 depth=0 variables=displacement file=E45d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.000 depth=0 variables=strains file=E46s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-118.000 depth=0 variables=displacement file=E46d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.000 depth=0 variables=strains file=E47s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-118.000 depth=0 variables=displacement file=E47d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.000 depth=0 variables=strains file=E48s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-118.000 depth=0 variables=displacement file=E48d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.000 depth=0 variables=strains file=E49s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-118.000 depth=0 variables=displacement file=E49d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.000 depth=0 variables=strains file=E50s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-118.000 depth=0 variables=displacement file=E50d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.000 depth=0 variables=strains file=E51s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-118.000 depth=0 variables=displacement file=E51d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.000 depth=0 variables=strains file=E52s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-118.000 depth=0 variables=displacement file=E52d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.000 depth=0 variables=strains file=E53s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-118.000 depth=0 variables=displacement file=E53d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.000 depth=0 variables=strains file=E54s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-118.000 depth=0 variables=displacement file=E54d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.000 depth=0 variables=strains file=E55s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-118.000 depth=0 variables=displacement file=E55d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.750 depth=0 variables=strains file=E56s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.750 depth=0 variables=displacement file=E56d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.750 depth=0 variables=strains file=E57s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.750 depth=0 variables=displacement file=E57d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.750 depth=0 variables=strains file=E58s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.750 depth=0 variables=displacement file=E58d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.750 depth=0 variables=strains file=E59s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.750 depth=0 variables=displacement file=E59d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.750 depth=0 variables=strains file=E60s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.750 depth=0 variables=displacement file=E60d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.750 depth=0 variables=strains file=E61s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.750 depth=0 variables=displacement file=E61d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.750 depth=0 variables=strains file=E62s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.750 depth=0 variables=displacement file=E62d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.750 depth=0 variables=strains file=E63s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.750 depth=0 variables=displacement file=E63d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.750 depth=0 variables=strains file=E64s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.750 depth=0 variables=displacement file=E64d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.750 depth=0 variables=strains file=E65s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.750 depth=0 variables=displacement file=E65d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.750 depth=0 variables=strains file=E66s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.750 depth=0 variables=displacement file=E66d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.500 depth=0 variables=strains file=E67s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.500 depth=0 variables=displacement file=E67d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.500 depth=0 variables=strains file=E68s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.500 depth=0 variables=displacement file=E68d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.500 depth=0 variables=strains file=E69s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.500 depth=0 variables=displacement file=E69d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.500 depth=0 variables=strains file=E70s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.500 depth=0 variables=displacement file=E70d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.500 depth=0 variables=strains file=E71s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.500 depth=0 variables=displacement file=E71d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.500 depth=0 variables=strains file=E72s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.500 depth=0 variables=displacement file=E72d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.500 depth=0 variables=strains file=E73s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.500 depth=0 variables=displacement file=E73d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.500 depth=0 variables=strains file=E74s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.500 depth=0 variables=displacement file=E74d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.500 depth=0 variables=strains file=E75s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.500 depth=0 variables=displacement file=E75d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.500 depth=0 variables=strains file=E76s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.500 depth=0 variables=displacement file=E76d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.500 depth=0 variables=strains file=E77s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.500 depth=0 variables=displacement file=E77d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.250 depth=0 variables=strains file=E78s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.250 depth=0 variables=displacement file=E78d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.250 depth=0 variables=strains file=E79s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.250 depth=0 variables=displacement file=E79d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.250 depth=0 variables=strains file=E80s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.250 depth=0 variables=displacement file=E80d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.250 depth=0 variables=strains file=E81s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.250 depth=0 variables=displacement file=E81d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.250 depth=0 variables=strains file=E82s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.250 depth=0 variables=displacement file=E82d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.250 depth=0 variables=strains file=E83s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.250 depth=0 variables=displacement file=E83d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.250 depth=0 variables=strains file=E84s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.250 depth=0 variables=displacement file=E84d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.250 depth=0 variables=strains file=E85s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.250 depth=0 variables=displacement file=E85d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.250 depth=0 variables=strains file=E86s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.250 depth=0 variables=displacement file=E86d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.250 depth=0 variables=strains file=E87s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.250 depth=0 variables=displacement file=E87d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.250 depth=0 variables=strains file=E88s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.250 depth=0 variables=displacement file=E88d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.000 depth=0 variables=strains file=E89s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-117.000 depth=0 variables=displacement file=E89d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.000 depth=0 variables=strains file=E90s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-117.000 depth=0 variables=displacement file=E90d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.000 depth=0 variables=strains file=E91s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-117.000 depth=0 variables=displacement file=E91d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.000 depth=0 variables=strains file=E92s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-117.000 depth=0 variables=displacement file=E92d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.000 depth=0 variables=strains file=E93s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-117.000 depth=0 variables=displacement file=E93d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.000 depth=0 variables=strains file=E94s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-117.000 depth=0 variables=displacement file=E94d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.000 depth=0 variables=strains file=E95s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-117.000 depth=0 variables=displacement file=E95d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.000 depth=0 variables=strains file=E96s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-117.000 depth=0 variables=displacement file=E96d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.000 depth=0 variables=strains file=E97s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-117.000 depth=0 variables=displacement file=E97d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.000 depth=0 variables=strains file=E98s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-117.000 depth=0 variables=displacement file=E98d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.000 depth=0 variables=strains file=E99s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-117.000 depth=0 variables=displacement file=E99d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.750 depth=0 variables=strains file=E100s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.750 depth=0 variables=displacement file=E100d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.750 depth=0 variables=strains file=E101s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.750 depth=0 variables=displacement file=E101d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.750 depth=0 variables=strains file=E102s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.750 depth=0 variables=displacement file=E102d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.750 depth=0 variables=strains file=E103s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.750 depth=0 variables=displacement file=E103d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.750 depth=0 variables=strains file=E104s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.750 depth=0 variables=displacement file=E104d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.750 depth=0 variables=strains file=E105s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.750 depth=0 variables=displacement file=E105d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.750 depth=0 variables=strains file=E106s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.750 depth=0 variables=displacement file=E106d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.750 depth=0 variables=strains file=E107s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.750 depth=0 variables=displacement file=E107d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.750 depth=0 variables=strains file=E108s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.750 depth=0 variables=displacement file=E108d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.750 depth=0 variables=strains file=E109s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.750 depth=0 variables=displacement file=E109d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.750 depth=0 variables=strains file=E110s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.750 depth=0 variables=displacement file=E110d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.500 depth=0 variables=strains file=E111s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.500 depth=0 variables=displacement file=E111d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.500 depth=0 variables=strains file=E112s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.500 depth=0 variables=displacement file=E112d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.500 depth=0 variables=strains file=E113s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.500 depth=0 variables=displacement file=E113d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.500 depth=0 variables=strains file=E114s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.500 depth=0 variables=displacement file=E114d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.500 depth=0 variables=strains file=E115s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.500 depth=0 variables=displacement file=E115d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.500 depth=0 variables=strains file=E116s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.500 depth=0 variables=displacement file=E116d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.500 depth=0 variables=strains file=E117s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.500 depth=0 variables=displacement file=E117d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.500 depth=0 variables=strains file=E118s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.500 depth=0 variables=displacement file=E118d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.500 depth=0 variables=strains file=E119s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.500 depth=0 variables=displacement file=E119d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.500 depth=0 variables=strains file=E120s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.500 depth=0 variables=displacement file=E120d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.500 depth=0 variables=strains file=E121s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.500 depth=0 variables=displacement file=E121d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.250 depth=0 variables=strains file=E122s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.250 depth=0 variables=displacement file=E122d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.250 depth=0 variables=strains file=E123s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.250 depth=0 variables=displacement file=E123d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.250 depth=0 variables=strains file=E124s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.250 depth=0 variables=displacement file=E124d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.250 depth=0 variables=strains file=E125s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.250 depth=0 variables=displacement file=E125d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.250 depth=0 variables=strains file=E126s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.250 depth=0 variables=displacement file=E126d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.250 depth=0 variables=strains file=E127s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.250 depth=0 variables=displacement file=E127d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.250 depth=0 variables=strains file=E128s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.250 depth=0 variables=displacement file=E128d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.250 depth=0 variables=strains file=E129s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.250 depth=0 variables=displacement file=E129d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.250 depth=0 variables=strains file=E130s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.250 depth=0 variables=displacement file=E130d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.250 depth=0 variables=strains file=E131s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.250 depth=0 variables=displacement file=E131d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.250 depth=0 variables=strains file=E132s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.250 depth=0 variables=displacement file=E132d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.000 depth=0 variables=strains file=E133s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.500 lon=-116.000 depth=0 variables=displacement file=E133d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.000 depth=0 variables=strains file=E134s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=34.750 lon=-116.000 depth=0 variables=displacement file=E134d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.000 depth=0 variables=strains file=E135s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.000 lon=-116.000 depth=0 variables=displacement file=E135d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.000 depth=0 variables=strains file=E136s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.250 lon=-116.000 depth=0 variables=displacement file=E136d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.000 depth=0 variables=strains file=E137s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.500 lon=-116.000 depth=0 variables=displacement file=E137d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.000 depth=0 variables=strains file=E138s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=35.750 lon=-116.000 depth=0 variables=displacement file=E138d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.000 depth=0 variables=strains file=E139s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.000 lon=-116.000 depth=0 variables=displacement file=E139d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.000 depth=0 variables=strains file=E140s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.250 lon=-116.000 depth=0 variables=displacement file=E140d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.000 depth=0 variables=strains file=E141s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.500 lon=-116.000 depth=0 variables=displacement file=E141d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.000 depth=0 variables=strains file=E142s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=36.750 lon=-116.000 depth=0 variables=displacement file=E142d usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.000 depth=0 variables=strains file=E143s usgsformat=1 sacformat=0 writeEvery=50
# rec lat=37.000 lon=-116.000 depth=0 variables=displacement file=E143d usgsformat=1 sacformat=0 writeEvery=50

# %% [markdown]
# ### Memory Calculations

# %% [markdown]
# Appendix B says roughly 208 bytes/grid point for runs with topography
#
# BUT "For parallel runs, the memory per grid point will be somewhat higher, because of duplicated
# ghost points at the processor boundaries."

# %%
grid_pts = (X/step_size) * (Y/step_size) * (depth_max / step_size)
mem_per_point = 208
mem_gb = grid_pts * mem_per_point / 1e9
print(f"Rough approximation of memory is {np.round(mem_gb, 0)} GB for a maximum frequency of {freqMax} Hz")
# Out:
# Rough approximation of memory is 67.0 GB for a maximum frequency of 0.1 Hz

# %% [markdown]
# ### Maximum Grid spacing

# %% [markdown]
# To have 30 super grid points on the outside of the domain and at least 60 actual grid points in domain, you can't have a step size for your grid higher than:

# %%
h_max = np.min([X/120, Y/120, depth_max/90])
h_max
# Out:
# 3315.054169166206
