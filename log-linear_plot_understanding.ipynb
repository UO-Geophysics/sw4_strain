# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,1,0.01)
y_1 = x
y_2 = 10**(2*x)
y_3 = 10**(3*x)
y_10 = 10**(10*x)

# %%
plt.plot(x, y_2, color = 'C0')
plt.plot(x, y_3, color = 'C1')
plt.plot(x, y_10, color = 'C1');

# %%
plt.plot(x, y_2, color = 'C0')
plt.plot(x, y_3, color = 'C1')
plt.plot(x, y_10, color = 'C2')
plt.semilogy()
plt.show();

plt.plot(x, 2*x)
plt.plot(x, 3*x)
plt.plot(x, 10*x)
plt.show()
